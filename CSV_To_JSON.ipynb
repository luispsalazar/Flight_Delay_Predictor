# %%
# Import Pandas Libraries

import pandas as pd

# %%
# Read CSV

csv_file = r'c:\Users\steph\Documents\Module_20\flightdelay_data.csv'
delays_df = pd.read_csv(csv_file, sep =',')
delays_df
# Out:
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0            1            7          0    0800-0859               2
# 1            1            7          0    0700-0759               7
# 2            1            7          0    0600-0659               7
# 3            1            7          0    0600-0659               9
# 4            1            7          0    0001-0559               7
# ...        ...          ...        ...          ...             ...
# 6489057     12            7          0    2300-2359               1
# 6489058     12            7          0    1800-1859               1
# 6489059     12            7          0    2000-2059               1
# 6489060     12            7          0    2100-2159               1
# 6489061     12            7          1    2100-2159               1
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0                     1                  25              143
# ...

# %%
delaysshort_df = delays_df[0:50]
delaysshort_df
# Out:
#     MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0       1            7          0    0800-0859               2
# 1       1            7          0    0700-0759               7
# 2       1            7          0    0600-0659               7
# 3       1            7          0    0600-0659               9
# 4       1            7          0    0001-0559               7
# 5       1            7          0    0001-0559               3
# 6       1            7          0    0700-0759               6
# 7       1            7          1    0001-0559               7
# 8       1            7          0    0001-0559               7
# 9       1            7          0    0600-0659               8
# 10      1            7          1    2300-2359               6
# 11      1            7          0    0600-0659               1
# 12      1            7          0    1200-1259               1
# 13      1            7          0    0600-0659               2
# ...

# %%
# Convert Pandas DataFrame to JSON
json_output = r'c:\Users\steph\Documents\Module_20\flightdelay_data.json'
output = delaysshort_df.to_json(json_output, indent = 1, orient='records')

# %%
# Convert Pandas DataFrame to JSON with Compression
json_output_compressed = r'c:\Users\steph\Documents\Module_20\flightdelay_data.json.gz'
output_compressed = delays_df.to_json(json_output_compressed, orient='records', indent = 1, compression='gzip')

# %%
# Read JSON Uncompressed
pd.read_json(json_output)
# Out:
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0            1            7          0    0800-0859               2
# 1            1            7          0    0700-0759               7
# 2            1            7          0    0600-0659               7
# 3            1            7          0    0600-0659               9
# 4            1            7          0    0001-0559               7
# ...        ...          ...        ...          ...             ...
# 6489057     12            7          0    2300-2359               1
# 6489058     12            7          0    1800-1859               1
# 6489059     12            7          0    2000-2059               1
# 6489060     12            7          0    2100-2159               1
# 6489061     12            7          1    2100-2159               1
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0                     1                  25              143
# ...

# %%
# Read JSON Compressed
pd.read_json(json_output_compressed)
# Out:
#          MONTH  DAY_OF_WEEK  DEP_DEL15 DEP_TIME_BLK  DISTANCE_GROUP  \
# 0            1            7          0    0800-0859               2
# 1            1            7          0    0700-0759               7
# 2            1            7          0    0600-0659               7
# 3            1            7          0    0600-0659               9
# 4            1            7          0    0001-0559               7
# ...        ...          ...        ...          ...             ...
# 6489057     12            7          0    2300-2359               1
# 6489058     12            7          0    1800-1859               1
# 6489059     12            7          0    2000-2059               1
# 6489060     12            7          0    2100-2159               1
# 6489061     12            7          1    2100-2159               1
#
#          SEGMENT_NUMBER  CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  \
# 0                     1                  25              143
# ...
