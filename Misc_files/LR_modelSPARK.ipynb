# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# !wget -q http://archive.apache.org/dist/spark/spark-3.1.1/spark-3.1.1-bin-hadoop3.2.tgz
# !tar xf spark-3.1.1-bin-hadoop3.2.tgz
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.1.1-bin-hadoop3.2"

# %%
import findspark
findspark.init()
from pyspark.sql import SparkSession
spark = SparkSession.builder.master("local[*]").getOrCreate()

# %%
# WARNING, FILE "delay_clean.csv" is > 4 GB  --  added to gitignore

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the csv into a dataframe
clean = spark.read.csv('/content/drive/MyDrive/Colab Notebooks/delay_clean.csv', header = True, inferSchema = True)
clean.limit(10)
# Out:
# DataFrame[MONTH: int, DAY_OF_WEEK: int, DEP_DEL15: int, DISTANCE_GROUP: int, SEGMENT_NUMBER: int, CONCURRENT_FLIGHTS: int, NUMBER_OF_SEATS: int, AIRPORT_FLIGHTS_MONTH: int, AIRLINE_FLIGHTS_MONTH: int, AIRLINE_AIRPORT_FLIGHTS_MONTH: int, AVG_MONTHLY_PASS_AIRPORT: int, AVG_MONTHLY_PASS_AIRLINE: int, FLT_ATTENDANTS_PER_PASS: double, GROUND_SERV_PER_PASS: double, PLANE_AGE: int, PREVIOUS_AIRPORT: string, PRCP: double, SNOW: double, SNWD: double, TMAX: double, AWND: double, DEP_TIME_BLK_0001-0559: double, DEP_TIME_BLK_0600-0659: double, DEP_TIME_BLK_0700-0759: double, DEP_TIME_BLK_0800-0859: double, DEP_TIME_BLK_0900-0959: double, DEP_TIME_BLK_1000-1059: double, DEP_TIME_BLK_1100-1159: double, DEP_TIME_BLK_1200-1259: double, DEP_TIME_BLK_1300-1359: double, DEP_TIME_BLK_1400-1459: double, DEP_TIME_BLK_1500-1559: double, DEP_TIME_BLK_1600-1659: double, DEP_TIME_BLK_1700-1759: double, DEP_TIME_BLK_1800-1859: double, DEP_TIME_BLK_1900-1959: double, DEP_TIME_BLK_2000-2059: double, DEP_TIME_BLK_2100-2159: double, DEP_TIME_BLK_2200-2259: double, DEP_TIME_BLK_2300-2359: double, CARRIER_NAME_Alaska Airlines Inc.: double, CARRIER_NAME_Allegiant Air: double, CARRIER_NAME_American Airlines Inc.: double, CARRIER_NAME_American Eagle Airlines Inc.: double, CARRIER_NAME_Atlantic Southeast Airlines: double, CARRIER_NAME_Comair Inc.: double, CARRIER_NAME_Delta Air Lines Inc.: double, CARRIER_NAME_Endeavor Air Inc.: double, CARRIER_NAME_Frontier Airlines Inc.: double, CARRIER_NAME_Hawaiian Airlines Inc.: double, CARRIER_NAME_JetBlue Airways: double, CARRIER_NAME_Mesa Airlines Inc.: double, CARRIER_NAME_Midwest Airline, Inc.: double, CARRIER_NAME_SkyWest Airlines Inc.: double, CARRIER_NAME_Southwest Airlines Co.: double, CARRIER_NAME_Spirit Air Lines: double, CARRIER_NAME_United Air Lines Inc.: double, DEPARTING_AIRPORT_Adams Field: double, DEPARTING_AIRPORT_Albany International: double, DEPARTING_AIRPORT_Albuquerque International Sunport: double, DEPARTING_AIRPORT_Anchorage International: double, DEPARTING_AIRPORT_Atlanta Municipal: double, DEPARTING_AIRPORT_Austin - Bergstrom International: double, DEPARTING_AIRPORT_Birmingham Airport: double, DEPARTING_AIRPORT_Boise Air Terminal: double, DEPARTING_AIRPORT_Bradley International: double, DEPARTING_AIRPORT_Charleston International: double, DEPARTING_AIRPORT_Chicago Midway International: double, DEPARTING_AIRPORT_Chicago O'Hare International: double, DEPARTING_AIRPORT_Cincinnati/Northern Kentucky International: double, DEPARTING_AIRPORT_Cleveland-Hopkins International: double, DEPARTING_AIRPORT_Dallas Fort Worth Regional: double, DEPARTING_AIRPORT_Dallas Love Field: double, DEPARTING_AIRPORT_Des Moines Municipal: double, DEPARTING_AIRPORT_Detroit Metro Wayne County: double, DEPARTING_AIRPORT_Douglas Municipal: double, DEPARTING_AIRPORT_El Paso International: double, DEPARTING_AIRPORT_Eppley Airfield: double, DEPARTING_AIRPORT_Fort Lauderdale-Hollywood International: double, DEPARTING_AIRPORT_Friendship International: double, DEPARTING_AIRPORT_General Mitchell Field: double, DEPARTING_AIRPORT_Greater Buffalo International: double, DEPARTING_AIRPORT_Greenville-Spartanburg: double, DEPARTING_AIRPORT_Hollywood-Burbank Midpoint: double, DEPARTING_AIRPORT_Honolulu International: double, DEPARTING_AIRPORT_Houston Intercontinental: double, DEPARTING_AIRPORT_Indianapolis Muni/Weir Cook: double, DEPARTING_AIRPORT_Jacksonville International: double, DEPARTING_AIRPORT_James M Cox/Dayton International: double, DEPARTING_AIRPORT_John F. Kennedy International: double, DEPARTING_AIRPORT_Kahului Airport: double, DEPARTING_AIRPORT_Kansas City International: double, DEPARTING_AIRPORT_Keahole: double, DEPARTING_AIRPORT_Kent County: double, DEPARTING_AIRPORT_LaGuardia: double, DEPARTING_AIRPORT_Lambert-St. Louis International: double, DEPARTING_AIRPORT_Lihue Airport: double, DEPARTING_AIRPORT_Logan International: double, DEPARTING_AIRPORT_Long Beach Daugherty Field: double, DEPARTING_AIRPORT_Los Angeles International: doub ...

# %% [markdown]
# ## Linear Regression

# %%
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.sql.types import IntegerType

# %%
clean = clean.withColumn("PREVIOUS_AIRPORT",clean["PREVIOUS_AIRPORT"].cast(IntegerType()))

# %%
clean.printSchema()
# Out:
# root
#  |-- MONTH: integer (nullable = true)
#  |-- DAY_OF_WEEK: integer (nullable = true)
#  |-- DEP_DEL15: integer (nullable = true)
#  |-- DISTANCE_GROUP: integer (nullable = true)
#  |-- SEGMENT_NUMBER: integer (nullable = true)
#  |-- CONCURRENT_FLIGHTS: integer (nullable = true)
#  |-- NUMBER_OF_SEATS: integer (nullable = true)
#  |-- AIRPORT_FLIGHTS_MONTH: integer (nullable = true)
#  |-- AIRLINE_FLIGHTS_MONTH: integer (nullable = true)
#  |-- AIRLINE_AIRPORT_FLIGHTS_MONTH: integer (nullable = true)
#  |-- AVG_MONTHLY_PASS_AIRPORT: integer (nullable = true)
#  |-- AVG_MONTHLY_PASS_AIRLINE: integer (nullable = true)
#  |-- FLT_ATTENDANTS_PER_PASS: double (nullable = true)
#  |-- GROUND_SERV_PER_PASS: double (nullable = true)
#  |-- PLANE_AGE: integer (nullable = true)
#  |-- PREVIOUS_AIRPORT: integer (nullable = true)
#  |-- PRCP: double (nullable = true)
#  |-- SNOW: double (nullable = true)
#  |-- SNWD: double (nullable = true)
#  |-- TMAX: double (nullable = true)
#  |-- AWND: double (nullable = true)
#  |-- DEP_TIME_BLK_0001-0559: double (nullable = true)
#  |-- DEP_TIME_BLK_0600-0659: double (nullable = true)
#  |-- DEP_TIME_BLK_0700-0759: double (nullable = true)
#  |-- DEP_TIME_BLK_0800-0859: double (nullable = true)
#  |-- DEP_TIME_BLK_0900-0959: double (nullable = true)
#  |-- DEP_TIME_BLK_1000-1059: double (nullable = true)
#  |-- DEP_TIME_BLK_1100-1159: double (nullable = true)
#  |-- DEP_TIME_BLK_1200-1259: double (nullable = true)
#  |-- DEP_TIME_BLK_1300-1359: double (nullable = true)
#  |-- DEP_TIME_BLK_1400-1459: double (nullable = true)
#  |-- DEP_TIME_BLK_1500-1559: double (nullable = true)
#  |-- DEP_TIME_BLK_1600-1659: double (nullable = true)
#  |-- DEP_TIME_BLK_1700-1759: double (nullable = true)
#  |-- DEP_TIME_BLK_1800-1859: double (nullable = true)
#  |-- DEP_TIME_BLK_1900-1959: double (nullable = true)
#  |-- DEP_TIME_BLK_2000-2059: double (nullable = true)
#  |-- DEP_TIME_BLK_2100-2159: double (nullable = true)
#  |-- DEP_TIME_BLK_2200-2259: double (nullable = true)
#  |-- DEP_TIME_BLK_2300-2359: double (nullable = true)
#  |-- CARRIER_NAME_Alaska Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Allegiant Air: double (nullable = true)
#  |-- CARRIER_NAME_American Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_American Eagle Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Atlantic Southeast Airlines: double (nullable = true)
#  |-- CARRIER_NAME_Comair Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Delta Air Lines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Endeavor Air Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Frontier Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Hawaiian Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_JetBlue Airways: double (nullable = true)
#  |-- CARRIER_NAME_Mesa Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Midwest Airline, Inc.: double (nullable = true)
#  |-- CARRIER_NAME_SkyWest Airlines Inc.: double (nullable = true)
#  |-- CARRIER_NAME_Southwest Airlines Co.: double (nullable = true)
#  |-- CARRIER_NAME_Spirit Air Lines: double (nullable = true)
#  |-- CARRIER_NAME_United Air Lines Inc.: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Adams Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Albany International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Albuquerque International Sunport: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Anchorage International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Atlanta Municipal: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Austin - Bergstrom International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Birmingham Airport: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Boise Air Terminal: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Bradley International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Charleston International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Chicago Midway International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Chicago O'Hare International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Cincinnati/Northern Kentucky International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Cleveland-Hopkins International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Dallas Fort Worth Regional: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Dallas Love Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Des Moines Municipal: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Detroit Metro Wayne County: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Douglas Municipal: double (nullable = true)
#  |-- DEPARTING_AIRPORT_El Paso International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Eppley Airfield: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Fort Lauderdale-Hollywood International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Friendship International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_General Mitchell Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Greater Buffalo International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Greenville-Spartanburg: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Hollywood-Burbank Midpoint: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Honolulu International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Houston Intercontinental: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Indianapolis Muni/Weir Cook: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Jacksonville International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_James M Cox/Dayton International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_John F. Kennedy International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Kahului Airport: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Kansas City International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Keahole: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Kent County: double (nullable = true)
#  |-- DEPARTING_AIRPORT_LaGuardia: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Lambert-St. Louis International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Lihue Airport: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Logan International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Long Beach Daugherty Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Los Angeles International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Louis Armstrong New Orleans International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_McCarran International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_McGhee Tyson: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Memphis International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Metropolitan Oakland International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Miami International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Minneapolis-St Paul International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Myrtle Beach International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Nashville International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Newark Liberty International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Norfolk International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Northwest Arkansas Regional: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Ontario International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Orange County: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Orlando International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Palm Beach International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Palm Springs International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Pensacola Regional: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Philadelphia International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Phoenix Sky Harbor International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Piedmont Triad International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Pittsburgh International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Port Columbus International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Portland International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Portland International Jetport: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Puerto Rico International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Raleigh-Durham International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Reno/Tahoe International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Richmond International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Rochester Monroe County: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Ronald Reagan Washington National: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Sacramento International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Salt Lake City International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_San Antonio International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_San Diego International Lindbergh Fl: double (nullable = true)
#  |-- DEPARTING_AIRPORT_San Francisco International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_San Jose International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Sanford NAS: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Savannah/Hilton Head International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Seattle International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Southwest Florida International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Spokane International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Standiford Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Stapleton International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Syracuse Hancock International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Tampa International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Theodore Francis Green State: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Truax Field: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Tucson International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Tulsa International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Washington Dulles International: double (nullable = true)
#  |-- DEPARTING_AIRPORT_Will Rogers World: double (nullable = true)
#  |-- DEPARTING_AIRPORT_William P Hobby: double (nullable = true)
#  |-- principal_component: double (nullable = true)

# %%
inputColList = clean.columns
inputColList
# Out:
# ['MONTH',
#  'DAY_OF_WEEK',
#  'DEP_DEL15',
#  'DISTANCE_GROUP',
#  'SEGMENT_NUMBER',
#  'CONCURRENT_FLIGHTS',
#  'NUMBER_OF_SEATS',
#  'AIRPORT_FLIGHTS_MONTH',
#  'AIRLINE_FLIGHTS_MONTH',
#  'AIRLINE_AIRPORT_FLIGHTS_MONTH',
#  'AVG_MONTHLY_PASS_AIRPORT',
#  'AVG_MONTHLY_PASS_AIRLINE',
#  'FLT_ATTENDANTS_PER_PASS',
#  'GROUND_SERV_PER_PASS',
#  'PLANE_AGE',
#  'PREVIOUS_AIRPORT',
#  'PRCP',
#  'SNOW',
#  'SNWD',
#  'TMAX',
#  'AWND',
#  'DEP_TIME_BLK_0001-0559',
#  'DEP_TIME_BLK_0600-0659',
#  'DEP_TIME_BLK_0700-0759',
#  'DEP_TIME_BLK_0800-0859',
#  'DEP_TIME_BLK_0900-0959',
#  'DEP_TIME_BLK_1000-1059',
#  'DEP_TIME_BLK_1100-1159',
#  'DEP_TIME_BLK_1200-1259',
#  'DEP_TIME_BLK_1300-1359',
#  'DEP_TIME_BLK_1400-1459',
#  'DEP_TIME_BLK_1500-1559',
#  'DEP_TIME_BLK_1600-1659',
#  'DEP_TIME_BLK_1700-1759',
#  'DEP_TIME_BLK_1800-1859',
#  'DEP_TIME_BLK_1900-1959',
#  'DEP_TIME_BLK_2000-2059',
#  'DEP_TIME_BLK_2100-2159',
#  'DEP_TIME_BLK_2200-2259',
#  'DEP_TIME_BLK_2300-2359',
#  'CARRIER_NAME_Alaska Airlines Inc.',
#  'CARRIER_NAME_Allegiant Air',
#  'CARRIER_NAME_American Airlines Inc.',
#  'CARRIER_NAME_American Eagle Airlines Inc.',
#  'CARRIER_NAME_Atlantic Southeast Airlines',
#  'CARRIER_NAME_Comair Inc.',
#  'CARRIER_NAME_Delta Air Lines Inc.',
#  'CARRIER_NAME_Endeavor Air Inc.',
#  'CARRIER_NAME_Frontier Airlines Inc.',
#  'CARRIER_NAME_Hawaiian Airlines Inc.',
#  'CARRIER_NAME_JetBlue Airways',
#  'CARRIER_NAME_Mesa Airlines Inc.',
#  'CARRIER_NAME_Midwest Airline, Inc.',
#  'CARRIER_NAME_SkyWest Airlines Inc.',
#  'CARRIER_NAME_Southwest Airlines Co.',
#  'CARRIER_NAME_Spirit Air Lines',
#  'CARRIER_NAME_United Air Lines Inc.',
#  'DEPARTING_AIRPORT_Adams Field',
#  'DEPARTING_AIRPORT_Albany International',
#  'DEPARTING_AIRPORT_Albuquerque International Sunport',
#  'DEPARTING_AIRPORT_Anchorage International',
#  'DEPARTING_AIRPORT_Atlanta Municipal',
#  'DEPARTING_AIRPORT_Austin - Bergstrom International',
#  'DEPARTING_AIRPORT_Birmingham Airport',
#  'DEPARTING_AIRPORT_Boise Air Terminal',
#  'DEPARTING_AIRPORT_Bradley International',
#  'DEPARTING_AIRPORT_Charleston International',
#  'DEPARTING_AIRPORT_Chicago Midway International',
#  "DEPARTING_AIRPORT_Chicago O'Hare International",
#  'DEPARTING_AIRPORT_Cincinnati/Northern Kentucky International',
#  'DEPARTING_AIRPORT_Cleveland-Hopkins International',
#  'DEPARTING_AIRPORT_Dallas Fort Worth Regional',
#  'DEPARTING_AIRPORT_Dallas Love Field',
#  'DEPARTING_AIRPORT_Des Moines Municipal',
#  'DEPARTING_AIRPORT_Detroit Metro Wayne County',
#  'DEPARTING_AIRPORT_Douglas Municipal',
#  'DEPARTING_AIRPORT_El Paso International',
#  'DEPARTING_AIRPORT_Eppley Airfield',
#  'DEPARTING_AIRPORT_Fort Lauderdale-Hollywood International',
#  'DEPARTING_AIRPORT_Friendship International',
#  'DEPARTING_AIRPORT_General Mitchell Field',
#  'DEPARTING_AIRPORT_Greater Buffalo International',
#  'DEPARTING_AIRPORT_Greenville-Spartanburg',
#  'DEPARTING_AIRPORT_Hollywood-Burbank Midpoint',
#  'DEPARTING_AIRPORT_Honolulu International',
#  'DEPARTING_AIRPORT_Houston Intercontinental',
#  'DEPARTING_AIRPORT_Indianapolis Muni/Weir Cook',
#  'DEPARTING_AIRPORT_Jacksonville International',
#  'DEPARTING_AIRPORT_James M Cox/Dayton International',
#  'DEPARTING_AIRPORT_John F. Kennedy International',
#  'DEPARTING_AIRPORT_Kahului Airport',
#  'DEPARTING_AIRPORT_Kansas City International',
#  'DEPARTING_AIRPORT_Keahole',
#  'DEPARTING_AIRPORT_Kent County',
#  'DEPARTING_AIRPORT_LaGuardia',
#  'DEPARTING_AIRPORT_Lambert-St. Louis International',
#  'DEPARTING_AIRPORT_Lihue Airport',
#  'DEPARTING_AIRPORT_Logan International',
#  'DEPARTING_AIRPORT_Long Beach Daugherty Field',
#  'DEPARTING_AIRPORT_Los Angeles International',
#  'DEPARTING_AIRPORT_Louis Armstrong New Orleans International',
#  'DEPARTING_AIRPORT_McCarran International',
#  'DEPARTING_AIRPORT_McGhee Tyson',
#  'DEPARTING_AIRPORT_Memphis International',
#  'DEPARTING_AIRPORT_Metropolitan Oakland International',
#  'DEPARTING_AIRPORT_Miami International',
#  'DEPARTING_AIRPORT_Minneapolis-St Paul International',
#  'DEPARTING_AIRPORT_Myrtle Beach International',
#  'DEPARTING_AIRPORT_Nashville International',
#  'DEPARTING_AIRPORT_Newark Liberty International',
#  'DEPARTING_AIRPORT_Norfolk International',
#  'DEPARTING_AIRPORT_Northwest Arkansas Regional',
#  'DEPARTING_AIRPORT_Ontario International',
#  'DEPARTING_AIRPORT_Orange County',
#  'DEPARTING_AIRPORT_Orlando International',
#  'DEPARTING_AIRPORT_Palm Beach International',
#  'DEPARTING_AIRPORT_Palm Springs International',
#  'DEPARTING_AIRPORT_Pensacola Regional',
#  'DEPARTING_AIRPORT_Philadelphia International',
#  'DEPARTING_AIRPORT_Phoenix Sky Harbor International',
#  'DEPARTING_AIRPORT_Piedmont Triad International',
#  'DEPARTING_AIRPORT_Pittsburgh International',
#  'DEPARTING_AIRPORT_Port Columbus International',
#  'DEPARTING_AIRPORT_Portland International',
#  'DEPARTING_AIRPORT_Portland International Jetport',
#  'DEPARTING_AIRPORT_Puerto Rico International',
#  'DEPARTING_AIRPORT_Raleigh-Durham International',
#  'DEPARTING_AIRPORT_Reno/Tahoe International',
#  'DEPARTING_AIRPORT_Richmond International',
#  'DEPARTING_AIRPORT_Rochester Monroe County',
#  'DEPARTING_AIRPORT_Ronald Reagan Washington National',
#  'DEPARTING_AIRPORT_Sacramento International',
#  'DEPARTING_AIRPORT_Salt Lake City International',
#  'DEPARTING_AIRPORT_San Antonio International',
#  'DEPARTING_AIRPORT_San Diego International Lindbergh Fl',
#  'DEPARTING_AIRPORT_San Francisco International',
#  'DEPARTING_AIRPORT_San Jose International',
#  'DEPARTING_AIRPORT_Sanford NAS',
#  'DEPARTING_AIRPORT_Savannah/Hilton Head International',
#  'DEPARTING_AIRPORT_Seattle International',
#  'DEPARTING_AIRPORT_Southwest Florida International',
#  'DEPARTING_AIRPORT_Spokane International',
#  'DEPARTING_AIRPORT_Standiford Field',
#  'DEPARTING_AIRPORT_Stapleton International',
#  'DEPARTING_AIRPORT_Syracuse Hancock International',
#  'DEPARTING_AIRPORT_Tampa International',
#  'DEPARTING_AIRPORT_Theodore Francis Green State',
#  'DEPARTING_AIRPORT_Truax Field',
#  'DEPARTING_AIRPORT_Tucson International',
#  'DEPARTING_AIRPORT_Tulsa International',
#  'DEPARTING_AIRPORT_Washington Dulles International',
#  'DEPARTING_AIRPORT_Will Rogers World',
#  'DEPARTING_AIRPORT_William P Hobby',
#  'principal_component']

# %%
#Input all the features in one vector column
assembler = VectorAssembler(inputCols = ['MONTH', 'DAY_OF_WEEK', 'DISTANCE_GROUP', 'SEGMENT_NUMBER',
 'CONCURRENT_FLIGHTS', 'NUMBER_OF_SEATS', 'AIRPORT_FLIGHTS_MONTH', 'AIRLINE_FLIGHTS_MONTH', 'AIRLINE_AIRPORT_FLIGHTS_MONTH',
 'AVG_MONTHLY_PASS_AIRPORT', 'AVG_MONTHLY_PASS_AIRLINE', 'FLT_ATTENDANTS_PER_PASS', 'GROUND_SERV_PER_PASS',
 'PLANE_AGE', 'PREVIOUS_AIRPORT',
 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'AWND', 'DEP_TIME_BLK_0001-0559', 'DEP_TIME_BLK_0600-0659', 'DEP_TIME_BLK_0700-0759',
 'DEP_TIME_BLK_0800-0859', 'DEP_TIME_BLK_0900-0959', 'DEP_TIME_BLK_1000-1059', 'DEP_TIME_BLK_1100-1159',
 'DEP_TIME_BLK_1200-1259', 'DEP_TIME_BLK_1300-1359', 'DEP_TIME_BLK_1400-1459', 'DEP_TIME_BLK_1500-1559',
 'DEP_TIME_BLK_1600-1659', 'DEP_TIME_BLK_1700-1759', 'DEP_TIME_BLK_1800-1859', 'DEP_TIME_BLK_1900-1959',
 'DEP_TIME_BLK_2000-2059', 'DEP_TIME_BLK_2100-2159', 'DEP_TIME_BLK_2200-2259', 'DEP_TIME_BLK_2300-2359',
 'CARRIER_NAME_Alaska Airlines Inc.', 'CARRIER_NAME_Allegiant Air', 'CARRIER_NAME_American Airlines Inc.',
 'CARRIER_NAME_American Eagle Airlines Inc.', 'CARRIER_NAME_Atlantic Southeast Airlines', 'CARRIER_NAME_Comair Inc.',
 'CARRIER_NAME_Delta Air Lines Inc.', 'CARRIER_NAME_Endeavor Air Inc.', 'CARRIER_NAME_Frontier Airlines Inc.',
 'CARRIER_NAME_Hawaiian Airlines Inc.', 'CARRIER_NAME_JetBlue Airways', 'CARRIER_NAME_Mesa Airlines Inc.',
 'CARRIER_NAME_Midwest Airline, Inc.', 'CARRIER_NAME_SkyWest Airlines Inc.', 'CARRIER_NAME_Southwest Airlines Co.',
 'CARRIER_NAME_Spirit Air Lines', 'CARRIER_NAME_United Air Lines Inc.', 'DEPARTING_AIRPORT_Adams Field',
 'DEPARTING_AIRPORT_Albany International', 'DEPARTING_AIRPORT_Albuquerque International Sunport',
 'DEPARTING_AIRPORT_Anchorage International', 'DEPARTING_AIRPORT_Atlanta Municipal',
 'DEPARTING_AIRPORT_Austin - Bergstrom International', 'DEPARTING_AIRPORT_Birmingham Airport',
 'DEPARTING_AIRPORT_Boise Air Terminal', 'DEPARTING_AIRPORT_Bradley International',
 'DEPARTING_AIRPORT_Charleston International', 'DEPARTING_AIRPORT_Chicago Midway International',
 "DEPARTING_AIRPORT_Chicago O'Hare International", 'DEPARTING_AIRPORT_Cincinnati/Northern Kentucky International',
 'DEPARTING_AIRPORT_Cleveland-Hopkins International', 'DEPARTING_AIRPORT_Dallas Fort Worth Regional',
 'DEPARTING_AIRPORT_Dallas Love Field', 'DEPARTING_AIRPORT_Des Moines Municipal',
 'DEPARTING_AIRPORT_Detroit Metro Wayne County', 'DEPARTING_AIRPORT_Douglas Municipal',
 'DEPARTING_AIRPORT_El Paso International',
 'DEPARTING_AIRPORT_Eppley Airfield',
 'DEPARTING_AIRPORT_Fort Lauderdale-Hollywood International',
 'DEPARTING_AIRPORT_Friendship International',
 'DEPARTING_AIRPORT_General Mitchell Field',
 'DEPARTING_AIRPORT_Greater Buffalo International',
 'DEPARTING_AIRPORT_Greenville-Spartanburg',
 'DEPARTING_AIRPORT_Hollywood-Burbank Midpoint',
 'DEPARTING_AIRPORT_Honolulu International',
 'DEPARTING_AIRPORT_Houston Intercontinental',
 'DEPARTING_AIRPORT_Indianapolis Muni/Weir Cook',
 'DEPARTING_AIRPORT_Jacksonville International',
 'DEPARTING_AIRPORT_James M Cox/Dayton International',
 'DEPARTING_AIRPORT_John F. Kennedy International',
 'DEPARTING_AIRPORT_Kahului Airport',
 'DEPARTING_AIRPORT_Kansas City International',
 'DEPARTING_AIRPORT_Keahole',
 'DEPARTING_AIRPORT_Kent County',
 'DEPARTING_AIRPORT_LaGuardia',
 'DEPARTING_AIRPORT_Lambert-St. Louis International',
 'DEPARTING_AIRPORT_Lihue Airport',
 'DEPARTING_AIRPORT_Logan International',
 'DEPARTING_AIRPORT_Long Beach Daugherty Field',
 'DEPARTING_AIRPORT_Los Angeles International',
 'DEPARTING_AIRPORT_Louis Armstrong New Orleans International',
 'DEPARTING_AIRPORT_McCarran International',
 'DEPARTING_AIRPORT_McGhee Tyson',
 'DEPARTING_AIRPORT_Memphis International',
 'DEPARTING_AIRPORT_Metropolitan Oakland International',
 'DEPARTING_AIRPORT_Miami International',
 'DEPARTING_AIRPORT_Minneapolis-St Paul International',
 'DEPARTING_AIRPORT_Myrtle Beach International',
 'DEPARTING_AIRPORT_Nashville International',
 'DEPARTING_AIRPORT_Newark Liberty International',
 'DEPARTING_AIRPORT_Norfolk International',
 'DEPARTING_AIRPORT_Northwest Arkansas Regional',
 'DEPARTING_AIRPORT_Ontario International',
 'DEPARTING_AIRPORT_Orange County',
 'DEPARTING_AIRPORT_Orlando International',
 'DEPARTING_AIRPORT_Palm Beach International',
 'DEPARTING_AIRPORT_Palm Springs International',
 'DEPARTING_AIRPORT_Pensacola Regional',
 'DEPARTING_AIRPORT_Philadelphia International',
 'DEPARTING_AIRPORT_Phoenix Sky Harbor International',
 'DEPARTING_AIRPORT_Piedmont Triad International',
 'DEPARTING_AIRPORT_Pittsburgh International',
 'DEPARTING_AIRPORT_Port Columbus International',
 'DEPARTING_AIRPORT_Portland International',
 'DEPARTING_AIRPORT_Portland International Jetport',
 'DEPARTING_AIRPORT_Puerto Rico International',
 'DEPARTING_AIRPORT_Raleigh-Durham International',
 'DEPARTING_AIRPORT_Reno/Tahoe International',
 'DEPARTING_AIRPORT_Richmond International',
 'DEPARTING_AIRPORT_Rochester Monroe County',
 'DEPARTING_AIRPORT_Ronald Reagan Washington National',
 'DEPARTING_AIRPORT_Sacramento International',
 'DEPARTING_AIRPORT_Salt Lake City International',
 'DEPARTING_AIRPORT_San Antonio International',
 'DEPARTING_AIRPORT_San Diego International Lindbergh Fl',
 'DEPARTING_AIRPORT_San Francisco International',
 'DEPARTING_AIRPORT_San Jose International',
 'DEPARTING_AIRPORT_Sanford NAS',
 'DEPARTING_AIRPORT_Savannah/Hilton Head International',
 'DEPARTING_AIRPORT_Seattle International',
 'DEPARTING_AIRPORT_Southwest Florida International',
 'DEPARTING_AIRPORT_Spokane International',
 'DEPARTING_AIRPORT_Standiford Field',
 'DEPARTING_AIRPORT_Stapleton International',
 'DEPARTING_AIRPORT_Syracuse Hancock International',
 'DEPARTING_AIRPORT_Tampa International',
 'DEPARTING_AIRPORT_Theodore Francis Green State',
 'DEPARTING_AIRPORT_Truax Field',
 'DEPARTING_AIRPORT_Tucson International',
 'DEPARTING_AIRPORT_Tulsa International',
 'DEPARTING_AIRPORT_Washington Dulles International',
 'DEPARTING_AIRPORT_Will Rogers World',
 'DEPARTING_AIRPORT_William P Hobby',
 'principal_component'], outputCol = 'DEP_DEL15')

# %%
output = assembler.transform(clean)
# Out:
# ---------------------------------------------------------------------------
# IllegalArgumentException                  Traceback (most recent call last)
# <ipython-input-40-24e4db27d3cc> in <module>()
# ----> 1 output = assembler.transform(clean)
#
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/ml/base.py in transform(self, dataset, params)
#     215                 return self.copy(params)._transform(dataset)
#     216             else:
# --> 217                 return self._transform(dataset)
#     218         else:
#     219             raise ValueError("Params must be a param map but got %s." % type(params))
#
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/ml/wrapper.py in _transform(self, dataset)
#     348     def _transform(self, dataset):
#     349         self._transfer_params_to_java()
# --> 350         return DataFrame(self._java_obj.transform(dataset._jdf), dataset.sql_ctx)
#     351
#     352
#
# /content/spark-3.1.1-bin-hadoop3.2/python/lib/py4j-0.10.9-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1303         answer = self.gateway_client.send_command(command)
#    1304         return_value = get_return_value(
# -> 1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#    1307         for temp_arg in temp_args:
#
# /content/spark-3.1.1-bin-hadoop3.2/python/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# IllegalArgumentException: Output column DEP_DEL15 already exists.

# %%
# Remove "DEP_DEL15" target (delayed more than 15 minutes) from features data

y = clean.select(col("DEP_DEL15")).collect()
X = clean.drop(col("DEP_DEL15"))

# %%
# Split training/test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 50, stratify = y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-cfd333099635> in <module>()
#       1 # Split training/test datasets
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 50, stratify = y)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2415         raise ValueError("At least one array required as input")
#    2416
# -> 2417     arrays = indexable(*arrays)
#    2418
#    2419     n_samples = _num_samples(arrays[0])
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in indexable(*iterables)
#     376
#     377     result = [_make_indexable(X) for X in iterables]
# --> 378     check_consistent_length(*result)
#     379     return result
#     380
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in <listcomp>(.0)
#     327     """
#     328
# --> 329     lengths = [_num_samples(X) for X in arrays if X is not None]
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in _num_samples(x)
#     263             x = np.asarray(x)
#     264         else:
# --> 265             raise TypeError(message)
#     266
#     267     if hasattr(x, "shape") and x.shape is not None:
#
# TypeError: Expected sequence or array-like, got <class 'pyspark.sql.dataframe.DataFrame'>

# %%
X_test.head()
# Out:
#          MONTH  DAY_OF_WEEK  DISTANCE_GROUP  SEGMENT_NUMBER  \
# 3980710      8            6               1               4
# 1460088      3            1               2               1
# 6282027     12            1               1               4
# 3063064      6            6               5               1
# 5992594     12            1               4               1
#
#          CONCURRENT_FLIGHTS  NUMBER_OF_SEATS  AIRPORT_FLIGHTS_MONTH  \
# 3980710                  24               50                  10855
# 1460088                   5               76                   4028
# 6282027                  60               66                  27188
# 3063064                  20              162                   6007
# 5992594                   6              143                   4098
#
#          AIRLINE_FLIGHTS_MONTH  AIRLINE_AIRPORT_FLIGHTS_MONTH  \
# 3980710                  28893                            339
# 1460088                  26929                           1118
# 6282027                  70473                           5294
# 3063064                  24204                            411
# 5992594                 113248                            868
#
#          AVG_MONTHLY_PASS_AIRPORT  ...  \
# 3980710                   1680928  ...
# 1460088                    344196  ...
# 6282027                   3103410  ...
# 3063064                    874468  ...
# 5992594                    385767  ...
#
#          DEPARTING_AIRPORT_Syracuse Hancock International  \
# 3980710                                               0.0
# 1460088                                               0.0
# 6282027                                               0.0
# 3063064                                               0.0
# 5992594                                               0.0
#
#          DEPARTING_AIRPORT_Tampa International  \
# 3980710                                    0.0
# 1460088                                    0.0
# 6282027                                    0.0
# 3063064                                    1.0
# 5992594                                    0.0
#
#          DEPARTING_AIRPORT_Theodore Francis Green State  \
# 3980710                                             0.0
# 1460088                                             0.0
# 6282027                                             0.0
# 3063064                                             0.0
# 5992594                                             0.0
#
#          DEPARTING_AIRPORT_Truax Field DEPARTING_AIRPORT_Tucson International  \
# 3980710                            0.0                                    0.0
# 1460088                            0.0                                    0.0
# 6282027                            0.0                                    0.0
# 3063064                            0.0                                    0.0
# 5992594                            0.0                                    0.0
#
#          DEPARTING_AIRPORT_Tulsa International  \
# 3980710                                    0.0
# 1460088                                    0.0
# 6282027                                    0.0
# 3063064                                    0.0
# 5992594                                    0.0
#
#          DEPARTING_AIRPORT_Washington Dulles International  \
# 3980710                                                0.0
# 1460088                                                0.0
# 6282027                                                0.0
# 3063064                                                0.0
# 5992594                                                0.0
#
#          DEPARTING_AIRPORT_Will Rogers World  \
# 3980710                                  0.0
# 1460088                                  0.0
# 6282027                                  0.0
# 3063064                                  0.0
# 5992594                                  0.0
#
#          DEPARTING_AIRPORT_William P Hobby  principal_component
# 3980710                                0.0           -20.625256
# 1460088                                0.0           -11.505072
# 6282027                                0.0            -6.564951
# 3063064                                0.0           -11.343075
# 5992594                                0.0           -14.165990
#
# [5 rows x 153 columns]

# %%
# Create a StandardScaler instance
scaler = StandardScaler()

# %%
# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# %%
# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create a random forest classifier
rf_model = RandomForestClassifier(n_estimators = 128, random_state = 50)

# %%
# Fitting the model
rf_model = rf_model.fit(X_train_scaled, y_train)

# %%
# Evaluate the model
y_pred = rf_model.predict(X_test_scaled)
print(f" Random forest predictive accuracy: {accuracy_score(y_test,y_pred):.3f}")
